# %% [markdown]
# # **Data Profiling**

# %% [markdown]
# # Explanatory Data Analysis
# ## Using Ydata-Profiling

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
# Loading data as df
file = Path.cwd().parents[1] /'data'/'processed' /  'data_for_profiling.csv' 
df = pd.read_csv(file, encoding='latin1')

# %% [markdown]
# # Creating Derived Columns

# %%
df.head(1)
# Out:
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 0   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category                       Product Name  \
# 0  FUR-BO-10001798  Furniture    Bookcases  Bush Somerset Collection Bookcase
#
#     Sales  Quantity  Discount   Profit
# 0  261.96         2       0.0  41.9136
#
# [1 rows x 21 columns]

# %%
# Adding Order Processing Time Column To The Dataframe
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df['Order Processing Time'] = df['Ship Date'] - df['Order Date']

# %%
df.head(10)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 5  Brosina Hoffman   Consumer  United States      Los Angeles  ...   West
# 6  Brosina Hoffman   Consumer  United States      Los Angeles  ...   West
# 7  Brosina Hoffman   Consumer  United States      Los Angeles  ...   West
# 8  Brosina Hoffman   Consumer  United States      Los Angeles  ...   West
# 9  Brosina Hoffman   Consumer  United States      Los Angeles  ...   West
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
# 5  FUR-FU-10001487        Furniture  Furnishings
# 6  OFF-AR-10002833  Office Supplies          Art
# 7  TEC-PH-10002275       Technology       Phones
# 8  OFF-BI-10003910  Office Supplies      Binders
# 9  OFF-AP-10002892  Office Supplies   Appliances
#
#                                         Product Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System   22.3680        2
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.8600        7
# 6                                         Newell 322    7.2800        4
# 7                     Mitel 5320 IP Phone VoIP phone  907.1520        6
# 8  DXL Angle-View Binders with Locking Rings by S...   18.5040        3
# 9                   Belkin F5C206VTEL 6 Outlet Surge  114.9000        5
#
#    Discount    Profit  Order Processing Time
# 0      0.00   41.9136                 3 days
# 1      0.00  219.5820                 3 days
# 2      0.00    6.8714                 4 days
# 3      0.45 -383.0310                 7 days
# 4      0.20    2.5164                 7 days
# 5      0.00   14.1694                 5 days
# 6      0.00    1.9656                 5 days
# 7      0.20   90.7152                 5 days
# 8      0.20    5.7825                 5 days
# 9      0.00   34.4700                 5 days
#
# [10 rows x 22 columns]

# %%
# Create a new nullable integer column with number of days (allows missing values)
df['Order Processing Time'] = pd.to_timedelta(df['Order Processing Time'], errors='coerce')
# Create a new nullable integer column with number of days (allows missing values)
df['Order Processing Days'] = df['Order Processing Time'].dt.days.astype('Int64')
df.head(10)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 5  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 6  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 7  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 8  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 9  Brosina Hoffman   Consumer  United States      Los Angeles  ...
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
# 5  FUR-FU-10001487        Furniture  Furnishings
# 6  OFF-AR-10002833  Office Supplies          Art
# 7  TEC-PH-10002275       Technology       Phones
# 8  OFF-BI-10003910  Office Supplies      Binders
# 9  OFF-AP-10002892  Office Supplies   Appliances
#
#                                         Product Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System   22.3680        2
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.8600        7
# 6                                         Newell 322    7.2800        4
# 7                     Mitel 5320 IP Phone VoIP phone  907.1520        6
# 8  DXL Angle-View Binders with Locking Rings by S...   18.5040        3
# 9                   Belkin F5C206VTEL 6 Outlet Surge  114.9000        5
#
#   Discount    Profit  Order Processing Time  Order Processing Days
# 0     0.00   41.9136                 3 days                      3
# 1     0.00  219.5820                 3 days                      3
# 2     0.00    6.8714                 4 days                      4
# 3     0.45 -383.0310                 7 days                      7
# 4     0.20    2.5164                 7 days                      7
# 5     0.00   14.1694                 5 days                      5
# 6     0.00    1.9656                 5 days                      5
# 7     0.20   90.7152                 5 days                      5
# 8     0.20    5.7825                 5 days                      5
# 9     0.00   34.4700                 5 days                      5
#
# [10 rows x 23 columns]

# %%
# Adding a Profit Margin Column
df['Profit Margin'] = (df['Profit']/df['Sales']).round(2)
df['Profit Margin']
df.head(10)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 5  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 6  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 7  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 8  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 9  Brosina Hoffman   Consumer  United States      Los Angeles  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# 2  Office Supplies        Labels
# 3        Furniture        Tables
# 4  Office Supplies       Storage
# 5        Furniture   Furnishings
# 6  Office Supplies           Art
# 7       Technology        Phones
# 8  Office Supplies       Binders
# 9  Office Supplies    Appliances
#
#                                         Product Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System   22.3680        2
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.8600        7
# 6                                         Newell 322    7.2800        4
# 7                     Mitel 5320 IP Phone VoIP phone  907.1520        6
# 8  DXL Angle-View Binders with Locking Rings by S...   18.5040        3
# 9                   Belkin F5C206VTEL 6 Outlet Surge  114.9000        5
#
#   Discount    Profit  Order Processing Time  Order Processing Days  \
# 0     0.00   41.9136                 3 days                      3
# 1     0.00  219.5820                 3 days                      3
# 2     0.00    6.8714                 4 days                      4
# 3     0.45 -383.0310                 7 days                      7
# 4     0.20    2.5164                 7 days                      7
# 5     0.00   14.1694                 5 days                      5
# 6     0.00    1.9656                 5 days                      5
# 7     0.20   90.7152                 5 days                      5
# 8     0.20    5.7825                 5 days                      5
# 9     0.00   34.4700                 5 days                      5
#
#    Profit Margin
# 0           0.16
# 1           0.30
# 2           0.47
# 3          -0.40
# 4           0.11
# 5           0.29
# 6           0.27
# 7           0.10
# 8           0.31
# 9           0.30
#
# [10 rows x 24 columns]

# %%
# Adding a  %Profit Margin Column
df['%Profit Margin'] = (df['Profit Margin'] * 100).round(2)
df['%Profit Margin']
# Out:
# 0       16.0
# 1       30.0
# 2       47.0
# 3      -40.0
# 4       11.0
#         ...
# 9989    16.0
# 9990    17.0
# 9991     8.0
# 9992    45.0
# 9993    30.0
# Name: %Profit Margin, Length: 9994, dtype: float64

# %%
# Creating A Year, Quarter and Month column for The Order and Ship Dates
df['Order Year'] = df['Order Date'].dt.year
df['Order Quarter'] = 'Q'+ df['Order Date'].dt.quarter.astype(str)
df['Order Month'] = df['Order Date'].dt.month_name().str[:]
df['Number Of Order Month'] = df['Order Date'].dt.month
df['Shipped Year'] = df['Ship Date'].dt.year
df['Shipped Quarter'] = "Q" + df['Ship Date'].dt.quarter.astype(str)
df['Shipped Month'] = df['Ship Date'].dt.month_name().str[:]
df['Number Of Shipped Month'] = df['Ship Date'].dt.month

# %%
df.head(3)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ... Profit Margin  \
# 0      Claire Gute   Consumer  United States    Henderson  ...          0.16
# 1      Claire Gute   Consumer  United States    Henderson  ...          0.30
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...          0.47
#
#    %Profit Margin Order Year Order Quarter Order Month Number Of Order Month  \
# 0            16.0       2016            Q4    November                    11
# 1            30.0       2016            Q4    November                    11
# 2            47.0       2016            Q2        June                     6
#
#   Shipped Year  Shipped Quarter  Shipped Month  Number Of Shipped Month
# 0         2016               Q4       November                       11
# 1         2016               Q4       November                       11
# 2         2016               Q2           June                        6
#
# [3 rows x 33 columns]

# %% [markdown]
# # Saving the processed dataframe

# %%
output = Path.cwd().parents[1] /'data'/'processed' / 'superstore_cleaned.csv' 
df.to_csv(output)

# %% [markdown]
# # Dataframe Dimensions

# %%
dim_customers = df[['Customer ID','Customer Name','Segment']]
dim_customers
# Out:
#      Customer ID     Customer Name    Segment
# 0       CG-12520       Claire Gute   Consumer
# 1       CG-12520       Claire Gute   Consumer
# 2       DV-13045   Darrin Van Huff  Corporate
# 3       SO-20335    Sean O'Donnell   Consumer
# 4       SO-20335    Sean O'Donnell   Consumer
# ...          ...               ...        ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer
# 9990    DB-13060       Dave Brooks   Consumer
# 9991    DB-13060       Dave Brooks   Consumer
# 9992    DB-13060       Dave Brooks   Consumer
# 9993    CC-12220      Chris Cortes   Consumer
#
# [9994 rows x 3 columns]

# %%
dim_products = df[['Product ID','Category','Sub-Category','Product Name']]
dim_products
# Out:
#            Product ID         Category Sub-Category  \
# 0     FUR-BO-10001798        Furniture    Bookcases
# 1     FUR-CH-10000454        Furniture       Chairs
# 2     OFF-LA-10000240  Office Supplies       Labels
# 3     FUR-TA-10000577        Furniture       Tables
# 4     OFF-ST-10000760  Office Supplies      Storage
# ...               ...              ...          ...
# 9989  FUR-FU-10001889        Furniture  Furnishings
# 9990  FUR-FU-10000747        Furniture  Furnishings
# 9991  TEC-PH-10003645       Technology       Phones
# 9992  OFF-PA-10004041  Office Supplies        Paper
# 9993  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name
# 0                     Bush Somerset Collection Bookcase
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2     Self-Adhesive Address Labels for Typewriters b...
# 3         Bretford CR4500 Series Slim Rectangular Table
# 4                        Eldon Fold 'N Roll Cart System
# ...                                                 ...
# 9989                             Ultra Door Pull Handle
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...
# 9991                              Aastra 57i VoIP phone
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...
#
# [9994 rows x 4 columns]

# %%
dim_geography = df[['Country','City','State','Postal Code','Region']]
dim_geography
# Out:
#             Country             City       State  Postal Code Region
# 0     United States        Henderson    Kentucky        42420  South
# 1     United States        Henderson    Kentucky        42420  South
# 2     United States      Los Angeles  California        90036   West
# 3     United States  Fort Lauderdale     Florida        33311  South
# 4     United States  Fort Lauderdale     Florida        33311  South
# ...             ...              ...         ...          ...    ...
# 9989  United States            Miami     Florida        33180  South
# 9990  United States       Costa Mesa  California        92627   West
# 9991  United States       Costa Mesa  California        92627   West
# 9992  United States       Costa Mesa  California        92627   West
# 9993  United States      Westminster  California        92683   West
#
# [9994 rows x 5 columns]

# %% [markdown]
# # FINAL EDA REPORT
# - EDA - Explanatory Data Analysis

# %%
profile = ProfileReport(df,title="EDA Report")

# %%
profile.to_file("../../reports/SuperstoreSalesFinalReport.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 33/33 [00:06<00:00,  4.99it/s]
# c:\Users\marcel\Documents\Data Analysis Projects\Superstore Sales Project\.venv\Lib\site-packages\ydata_profiling\model\pandas\discretize_pandas.py:52: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[4 4 5 ... 7 7 7]' has dtype incompatible with timedelta64[ns], please explicitly cast to a compatible dtype first.
#   discretized_df.loc[:, column] = self._discretize_column(
# c:\Users\marcel\Documents\Data Analysis Projects\Superstore Sales Project\.venv\Lib\site-packages\ydata_profiling\model\pandas\discretize_pandas.py:52: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[6 6 6 ... 9 9 9]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   discretized_df.loc[:, column] = self._discretize_column(
# c:\Users\marcel\Documents\Data Analysis Projects\Superstore Sales Project\.venv\Lib\site-packages\ydata_profiling\model\pandas\discretize_pandas.py:52: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[9 9 4 ... 0 0 3]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   discretized_df.loc[:, column] = self._discretize_column(
# c:\Users\marcel\Documents\Data Analysis Projects\Superstore Sales Project\.venv\Lib\site-packages\ydata_profiling\model\pandas\discretize_pandas.py:52: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[4 4 4 ... 7 7 7]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   discretized_df.loc[:, column] = self._discretize_column(
# c:\Users\marcel\Documents\Data Analysis Projects\Superstore Sales Project\.venv\Lib\site-packages\ydata_profiling\model\pandas\discretize_pandas.py:52: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[9 9 4 ... 1 1 3]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   discretized_df.loc[:, column] = self._discretize_column(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
